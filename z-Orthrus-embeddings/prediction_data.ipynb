# %%
import pandas as pd
import polars as pl

import xgboost as xgb
from sklearn.model_selection import GridSearchCV, RandomizedSearchCV
import sklearn.utils

# %%
label_table = pd.read_csv("../../../../../../../../s/project/gene_embedding/modeling_splits/disease_gene_splits.tsv", sep = '\t')
label_table = label_table.set_index('gene_id')
label_table
# Out:
#                  target  train   test  fold     disease  min_auprc short_name
# gene_id
# ENSG00000198888   False   True  False     1  Hematology   0.002492        HEM
# ENSG00000198763   False   True  False     1  Hematology   0.002492        HEM
# ENSG00000198804   False   True  False     1  Hematology   0.002492        HEM
# ENSG00000198712   False   True  False     1  Hematology   0.002492        HEM
# ENSG00000228253   False   True  False     1  Hematology   0.002492        HEM
# ...                 ...    ...    ...   ...         ...        ...        ...
# ENSG00000143367   False   True  False     5          tg   0.000865         TG
# ENSG00000143442   False   True  False     5          tg   0.000865         TG
# ENSG00000117676   False   True  False     5          tg   0.000865         TG
# ENSG00000284733   False  False   True     5          tg   0.000865         TG
# ENSG00000117682   False   True  False     5          tg   0.000865         TG
#
# ...
